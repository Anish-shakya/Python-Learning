# %%
# Pre-defined lists
names = ['United States', 'Australia', 'Japan', 'India', 'Russia', 'Morocco', 'Egypt']
dr =  [True, False, False, False, True, True, True]
cpc = [809, 731, 588, 18, 200, 70, 45]

# %%
my_dict = {
'country':names,
'drives_right':dr,
'cars_per_cap':cpc
}
my_dict
# Out:
# {'country': ['United States',
#   'Australia',
#   'Japan',
#   'India',
#   'Russia',
#   'Morocco',
#   'Egypt'],
#  'drives_right': [True, False, False, False, True, True, True],
#  'cars_per_cap': [809, 731, 588, 18, 200, 70, 45]}

# %%
import pandas as pd

# %%
cars =pd.DataFrame(my_dict)
cars
# Out:
#          country  drives_right  cars_per_cap
# 0  United States          True           809
# 1      Australia         False           731
# 2          Japan         False           588
# 3          India         False            18
# 4         Russia          True           200
# 5        Morocco          True            70
# 6          Egypt          True            45

# %% [markdown]
# ### Reading CVS File

# %%
import pandas as pd

# %%
df = pd.read_csv('Mt.Everest Summiters.csv')
df
# Out:
#        _id                     NAME      COUNTRY  DAY  MONTH  YEAR     ROUTE  \
# 0        1           TENZING NORGAY        NEPAL   29      5  1953  SOUTHCOL
# 1        2           EDMUND HILLARY  NEW ZEALAND   29      5  1953  SOUTHCOL
# 2        3            ERNST SCHMIED  SWITZERLAND   23      5  1956  SOUTHCOL
# 3        4            JUERGE MARMET  SWITZERLAND   23      5  1956  SOUTHCOL
# 4        5              ADOLF REIST  SWITZERLAND   24      5  1956  SOUTHCOL
# ...    ...                      ...          ...  ...    ...   ...       ...
# 5296  5297    MR. PEMBA RITA SHERPA        NEPAL   27      5  2017       NaN
# 5297  5298       MR. PASANG GYALZEN        NEPAL   27      5  2017       NaN
# 5298  5299  MR. MINGMA DORJI SHERPA        NEPAL   16      5  2017       NaN
# 5299  5300    MR. DAWA SANGE SHERPA        NEPAL   21      5  2017       NaN
# 5300  5301         MR. PASANG BHOTE        NEPAL   21      5  2017       NaN
#
#             NAME OF THE TEAM          LEADER
# ...

# %%
df.shape
df.describe()
# Out:
#                _id          DAY        MONTH         YEAR
# count  5301.000000  5301.000000  5301.000000  5301.000000
# mean   2651.000000    19.540841     5.251651  2007.150915
# std    1530.411219     5.384541     1.171380     9.323426
# min       1.000000     1.000000     1.000000  1953.000000
# 25%    1326.000000    17.000000     5.000000  2004.000000
# 50%    2651.000000    20.000000     5.000000  2009.000000
# 75%    3976.000000    23.000000     5.000000  2013.000000
# max    5301.000000    31.000000    12.000000  2088.000000

# %% [markdown]
# ### Selecting data

# %%
data_dict ={
    'Name' : ['Anish shakya','Manish Shakya','Sanish Shakya'],
    'Age' : [22,21,23],
    'Occupation' :['Data and Business Intelligence analyst','Data Analyst','Data Engineer'],
    'Office' : ['iSend Global','Fintech','iSend'],
    'Location': ['Australia','USA','Japan']
}

# %%
df = pd.DataFrame(data_dict)
df
# Out:
#             Name  Age                              Occupation        Office  \
# 0   Anish shakya   22  Data and Business Intelligence analyst  iSend Global
# 1  Manish Shakya   21                            Data Analyst       Fintech
# 2  Sanish Shakya   23                           Data Engineer         iSend
#
#     Location
# 0  Australia
# 1        USA
# 2      Japan

# %%
data = pd.read_csv('Mt.Everest Summiters.csv',index_col=0)
data
# Out:
#                          NAME      COUNTRY  DAY  MONTH  YEAR     ROUTE  \
# _id
# 1              TENZING NORGAY        NEPAL   29      5  1953  SOUTHCOL
# 2              EDMUND HILLARY  NEW ZEALAND   29      5  1953  SOUTHCOL
# 3               ERNST SCHMIED  SWITZERLAND   23      5  1956  SOUTHCOL
# 4               JUERGE MARMET  SWITZERLAND   23      5  1956  SOUTHCOL
# 5                 ADOLF REIST  SWITZERLAND   24      5  1956  SOUTHCOL
# ...                       ...          ...  ...    ...   ...       ...
# 5297    MR. PEMBA RITA SHERPA        NEPAL   27      5  2017       NaN
# 5298       MR. PASANG GYALZEN        NEPAL   27      5  2017       NaN
# 5299  MR. MINGMA DORJI SHERPA        NEPAL   16      5  2017       NaN
# 5300    MR. DAWA SANGE SHERPA        NEPAL   21      5  2017       NaN
# 5301         MR. PASANG BHOTE        NEPAL   21      5  2017       NaN
#
#             NAME OF THE TEAM          LEADER
# _id
# 1         BRITISH EXPEDITION  Lord John Hunt
# ...

# %% [markdown]
# ## Acessing Data From Dataframe

# %%
type(data['NAME'])
type(data[['NAME']])
# Out:
# pandas.core.frame.DataFrame

# %%
data[
# Out:
#                          NAME
# _id
# 1              TENZING NORGAY
# 2              EDMUND HILLARY
# 3               ERNST SCHMIED
# 4               JUERGE MARMET
# 5                 ADOLF REIST
# ...                       ...
# 5297    MR. PEMBA RITA SHERPA
# 5298       MR. PASANG GYALZEN
# 5299  MR. MINGMA DORJI SHERPA
# 5300    MR. DAWA SANGE SHERPA
# 5301         MR. PASANG BHOTE
#
# [5301 rows x 1 columns]

# %% [markdown]
# # Loc and iLoc
# ## Loc
# Loc is based in label names
# ## iLoc
# iLoc is based on integer or position of the data columns

# %%
data.loc[[1]]
# Out:
#                NAME COUNTRY  DAY  MONTH  YEAR     ROUTE    NAME OF THE TEAM  \
# _id
# 1    TENZING NORGAY   NEPAL   29      5  1953  SOUTHCOL  BRITISH EXPEDITION
#
#              LEADER
# _id
# 1    Lord John Hunt

# %%
data.iloc[:,[0,3]]
# Out:
#                          NAME  MONTH
# _id
# 1              TENZING NORGAY      5
# 2              EDMUND HILLARY      5
# 3               ERNST SCHMIED      5
# 4               JUERGE MARMET      5
# 5                 ADOLF REIST      5
# ...                       ...    ...
# 5297    MR. PEMBA RITA SHERPA      5
# 5298       MR. PASANG GYALZEN      5
# 5299  MR. MINGMA DORJI SHERPA      5
# 5300    MR. DAWA SANGE SHERPA      5
# 5301         MR. PASANG BHOTE      5
#
# [5301 rows x 2 columns]

# %%
import numpy as np
np.random.seed(123)

outcomes=[]

for x in range(20):
    if np.random.randint(0,2) == 0:
        outcomes.append('Head')
    else:
        outcomes.append('Tail')

outcomes
# Out:
# ['Head',
#  'Tail',
#  'Head',
#  'Head',
#  'Head',
#  'Head',
#  'Head',
#  'Tail',
#  'Tail',
#  'Head',
#  'Tail',
#  'Tail',
#  'Head',
#  'Tail',
#  'Head',
#  'Tail',
#  'Head',
#  'Tail',
#  'Tail',
#  'Head']

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(123)

final_tails=[]

for x in range(1000000):
    tails = [0]
    for x in range(10):
        coin = np.random.randint(0,2)
        tails.append(tails[x]+coin)
    final_tails.append(tails[-1])

plt.hist(final_tails,bins=10)
plt.show()
